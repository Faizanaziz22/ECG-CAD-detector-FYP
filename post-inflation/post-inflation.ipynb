# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# ✅ Folder path jahan .ekg files hain
folder_path = r"C:\Users\faizan\ECG_detection\post-inflation"

# ✅ Bandpass Filter Function (0.5 - 50 Hz)
def bandpass_filter(signal, lowcut=0.5, highcut=50.0, fs=500, order=3):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype="band")
    return filtfilt(b, a, signal)

# ✅ Function to Read & Process ECG Signals
def read_and_process_ecg(file_path):
    try:
        # ✅ ECG data read karna
        ecg_signal = np.fromfile(file_path, dtype=np.int16)  # Check dtype

        # ✅ Check if the signal is empty
        if ecg_signal.size == 0:
            print(f"⚠️ Warning: {file_path} is empty!")
            return None

        # ✅ Normalize Signal (Scale between -1 to 1)
        ecg_signal = ecg_signal / np.max(np.abs(ecg_signal))

        # ✅ Apply Bandpass Filter
        ecg_filtered = bandpass_filter(ecg_signal)

        return ecg_filtered

    except Exception as e:
        print(f"❌ Error reading {file_path}: {e}")
        return None

# ✅ Get all .ekg files
file_names = [f for f in os.listdir(folder_path) if f.endswith(".ekg")]

if not file_names:
    print("⚠️ No .ekg files found in the folder!")
else:
    print(f"📂 Found {len(file_names)} .ekg files")

    # ✅ Process all files
    for file_name in file_names:
        file_path = os.path.join(folder_path, file_name)
        print(f"📄 Processing {file_name}")

        ecg_signal = read_and_process_ecg(file_path)

        if ecg_signal is not None:
            print(f"✅ ECG Signal Processed! Length: {len(ecg_signal)} samples")

            # ✅ Plot Processed ECG Signal
            plt.figure(figsize=(12, 4))
            plt.plot(ecg_signal[:500], color='green')  # Plot first 500 samples
            plt.title(f"Processed ECG Signal: {file_name}")
            plt.xlabel("Time (samples)")
            plt.ylabel("Normalized Amplitude")
            plt.grid()
            plt.show()
        else:
            print(f"❌ Could not process {file_name}")
# Out:
# 📂 Found 74 .ekg files
# 📄 Processing P1.ekg
# ✅ ECG Signal Processed! Length: 251624 samples
# 📄 Processing P10.ekg
# ✅ ECG Signal Processed! Length: 365244 samples
# 📄 Processing P11.ekg
# ✅ ECG Signal Processed! Length: 228824 samples
# 📄 Processing P12.ekg
# ✅ ECG Signal Processed! Length: 319024 samples
# 📄 Processing P13.ekg
# ✅ ECG Signal Processed! Length: 495724 samples
# 📄 Processing P14.ekg
# ✅ ECG Signal Processed! Length: 290664 samples
# 📄 Processing P15.ekg
# ✅ ECG Signal Processed! Length: 323604 samples
# 📄 Processing P16.ekg
# ✅ ECG Signal Processed! Length: 296244 samples
# 📄 Processing P17.ekg
# ✅ ECG Signal Processed! Length: 494124 samples
# 📄 Processing P18.ekg
# ✅ ECG Signal Processed! Length: 269524 samples
# 📄 Processing P19.ekg
# ✅ ECG Signal Processed! Length: 219704 samples
# 📄 Processing P2.ekg
# ✅ ECG Signal Processed! Length: 358744 samples
# 📄 Processing P20.ekg
# ✅ ECG Signal Processed! Length: 228624 samples
# 📄 Processing P21.ekg
# ✅ ECG Signal Processed! Length: 251624 samples
# 📄 Processing P22.ekg
# ✅ ECG Signal Processed! Length: 394364 samples
# 📄 Processing P23.ekg
# ✅ ECG Signal Processed! Length: 491004 samples
# 📄 Processing P24.ekg
# ✅ ECG Signal Processed! Length: 251624 samples
# 📄 Processing P25.ekg
# ✅ ECG Signal Processed! Length: 491004 samples
# 📄 Processing P26.ekg
# ✅ ECG Signal Processed! Length: 340364 samples
# 📄 Processing P27.ekg
# ✅ ECG Signal Processed! Length: 236564 samples
# 📄 Processing P28.ekg
# ✅ ECG Signal Processed! Length: 275964 samples
# 📄 Processing P29.ekg
# ✅ ECG Signal Processed! Length: 284784 samples
# 📄 Processing P3.ekg
# ✅ ECG Signal Processed! Length: 437704 samples
# 📄 Processing P30.ekg
# ✅ ECG Signal Processed! Length: 608024 samples
# 📄 Processing P31.ekg
# ✅ ECG Signal Processed! Length: 589024 samples
# 📄 Processing P32.ekg
# ✅ ECG Signal Processed! Length: 331404 samples
# 📄 Processing P33.ekg
# ✅ ECG Signal Processed! Length: 343344 samples
# 📄 Processing P34.ekg
# ✅ ECG Signal Processed! Length: 499724 samples
# 📄 Processing P35.ekg
# ✅ ECG Signal Processed! Length: 361024 samples
# 📄 Processing P36.ekg
# ✅ ECG Signal Processed! Length: 367464 samples
# 📄 Processing P37.ekg
# ✅ ECG Signal Processed! Length: 365124 samples
# 📄 Processing P38.ekg
# ✅ ECG Signal Processed! Length: 357104 samples
# 📄 Processing P39.ekg
# ✅ ECG Signal Processed! Length: 248104 samples
# 📄 Processing P4.ekg
# ✅ ECG Signal Processed! Length: 216424 samples
# 📄 Processing P40.ekg
# ✅ ECG Signal Processed! Length: 606384 samples
# 📄 Processing P41.ekg
# ✅ ECG Signal Processed! Length: 291444 samples
# 📄 Processing P42.ekg
# ✅ ECG Signal Processed! Length: 306244 samples
# 📄 Processing P43.ekg
# ✅ ECG Signal Processed! Length: 257984 samples
# 📄 Processing P44.ekg
# ✅ ECG Signal Processed! Length: 257984 samples
# 📄 Processing P45.ekg
# ✅ ECG Signal Processed! Length: 244544 samples
# 📄 Processing P46.ekg
# ✅ ECG Signal Processed! Length: 222884 samples
# 📄 Processing P47.ekg
# ✅ ECG Signal Processed! Length: 231484 samples
# 📄 Processing P48.ekg
# ✅ ECG Signal Processed! Length: 257084 samples
# 📄 Processing P49.ekg
# ✅ ECG Signal Processed! Length: 548104 samples
# 📄 Processing P5.ekg
# ✅ ECG Signal Processed! Length: 229104 samples
# 📄 Processing P50.ekg
# ✅ ECG Signal Processed! Length: 382564 samples
# 📄 Processing P51.ekg
# ✅ ECG Signal Processed! Length: 274184 samples
# 📄 Processing P52.ekg
# ✅ ECG Signal Processed! Length: 283644 samples
# 📄 Processing P53.ekg
# ✅ ECG Signal Processed! Length: 486504 samples
# 📄 Processing P54.ekg
# ✅ ECG Signal Processed! Length: 227344 samples
# 📄 Processing P55.ekg
# ✅ ECG Signal Processed! Length: 464304 samples
# 📄 Processing P56.ekg
# ✅ ECG Signal Processed! Length: 269684 samples
# 📄 Processing P57.ekg
# ✅ ECG Signal Processed! Length: 249544 samples
# 📄 Processing P58.ekg
# ✅ ECG Signal Processed! Length: 314804 samples
# 📄 Processing P59.ekg
# ✅ ECG Signal Processed! Length: 287444 samples
# 📄 Processing P6.ekg
# ✅ ECG Signal Processed! Length: 231644 samples
# 📄 Processing P60.ekg
# ✅ ECG Signal Processed! Length: 425724 samples
# 📄 Processing P61.ekg
# ✅ ECG Signal Processed! Length: 445624 samples
# 📄 Processing P62.ekg
# ✅ ECG Signal Processed! Length: 385264 samples
# 📄 Processing P63.ekg
# ✅ ECG Signal Processed! Length: 309664 samples
# 📄 Processing P64.ekg
# ✅ ECG Signal Processed! Length: 394364 samples
# 📄 Processing P65.ekg
# ✅ ECG Signal Processed! Length: 258364 samples
# 📄 Processing P66.ekg
# ✅ ECG Signal Processed! Length: 435404 samples
# 📄 Processing P67.ekg
# ✅ ECG Signal Processed! Length: 347564 samples
# 📄 Processing P68.ekg
# ✅ ECG Signal Processed! Length: 343784 samples
# 📄 Processing P69.ekg
# ✅ ECG Signal Processed! Length: 237764 samples
# 📄 Processing P7.ekg
# ✅ ECG Signal Processed! Length: 208864 samples
# 📄 Processing P70.ekg
# ✅ ECG Signal Processed! Length: 277324 samples
# 📄 Processing P71.ekg
# ✅ ECG Signal Processed! Length: 280184 samples
# 📄 Processing P72.ekg
# ✅ ECG Signal Processed! Length: 309084 samples
# 📄 Processing P73.ekg
# ✅ ECG Signal Processed! Length: 233684 samples
# 📄 Processing P74.ekg
# ✅ ECG Signal Processed! Length: 256584 samples
# 📄 Processing P8.ekg
# ✅ ECG Signal Processed! Length: 302244 samples
# 📄 Processing P9.ekg
# ✅ ECG Signal Processed! Length: 367724 samples
