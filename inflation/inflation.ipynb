# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# ✅ Folder path jahan .ekg files hain
folder_path = r"C:\Users\faizan\ECG_detection\inflation"

# ✅ Bandpass Filter Function (0.5 - 50 Hz)
def bandpass_filter(signal, lowcut=0.5, highcut=50.0, fs=500, order=3):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype="band")
    return filtfilt(b, a, signal)

# ✅ Function to Read & Process ECG Signals
def read_and_process_ecg(file_path):
    try:
        # ✅ ECG data read karna
        ecg_signal = np.fromfile(file_path, dtype=np.int16)  # Check dtype

        # ✅ Check if the signal is empty
        if ecg_signal.size == 0:
            print(f"⚠️ Warning: {file_path} is empty!")
            return None

        # ✅ Normalize Signal (Scale between -1 to 1)
        ecg_signal = ecg_signal / np.max(np.abs(ecg_signal))

        # ✅ Apply Bandpass Filter
        ecg_filtered = bandpass_filter(ecg_signal)

        return ecg_filtered

    except Exception as e:
        print(f"❌ Error reading {file_path}: {e}")
        return None

# ✅ Get all .ekg files
file_names = [f for f in os.listdir(folder_path) if f.endswith(".ekg")]

if not file_names:
    print("⚠️ No .ekg files found in the folder!")
else:
    print(f"📂 Found {len(file_names)} .ekg files")

    # ✅ Process all files
    for file_name in file_names:
        file_path = os.path.join(folder_path, file_name)
        print(f"📄 Processing {file_name}")

        ecg_signal = read_and_process_ecg(file_path)

        if ecg_signal is not None:
            print(f"✅ ECG Signal Processed! Length: {len(ecg_signal)} samples")

            # ✅ Plot Processed ECG Signal
            plt.figure(figsize=(12, 4))
            plt.plot(ecg_signal[:500], color='green')  # Plot first 500 samples
            plt.title(f"Processed ECG Signal: {file_name}")
            plt.xlabel("Time (samples)")
            plt.ylabel("Normalized Amplitude")
            plt.grid()
            plt.show()
        else:
            print(f"❌ Could not process {file_name}")
# Out:
# 📂 Found 74 .ekg files
# 📄 Processing P1.ekg
# ✅ ECG Signal Processed! Length: 255624 samples
# 📄 Processing P10.ekg
# ✅ ECG Signal Processed! Length: 431524 samples
# 📄 Processing P11.ekg
# ✅ ECG Signal Processed! Length: 274284 samples
# 📄 Processing P12.ekg
# ✅ ECG Signal Processed! Length: 289504 samples
# 📄 Processing P13.ekg
# ✅ ECG Signal Processed! Length: 431464 samples
# 📄 Processing P14.ekg
# ✅ ECG Signal Processed! Length: 1564104 samples
# 📄 Processing P15.ekg
# ✅ ECG Signal Processed! Length: 487884 samples
# 📄 Processing P16.ekg
# ✅ ECG Signal Processed! Length: 409324 samples
# 📄 Processing P17.ekg
# ✅ ECG Signal Processed! Length: 1370484 samples
# 📄 Processing P18.ekg
# ✅ ECG Signal Processed! Length: 702264 samples
# 📄 Processing P19.ekg
# ✅ ECG Signal Processed! Length: 278104 samples
# 📄 Processing P2.ekg
# ✅ ECG Signal Processed! Length: 373324 samples
# 📄 Processing P20.ekg
# ✅ ECG Signal Processed! Length: 257444 samples
# 📄 Processing P21.ekg
# ✅ ECG Signal Processed! Length: 255624 samples
# 📄 Processing P22.ekg
# ✅ ECG Signal Processed! Length: 235344 samples
# 📄 Processing P23.ekg
# ✅ ECG Signal Processed! Length: 473024 samples
# 📄 Processing P24.ekg
# ✅ ECG Signal Processed! Length: 255624 samples
# 📄 Processing P25.ekg
# ✅ ECG Signal Processed! Length: 473024 samples
# 📄 Processing P26.ekg
# ✅ ECG Signal Processed! Length: 786184 samples
# 📄 Processing P27.ekg
# ✅ ECG Signal Processed! Length: 357464 samples
# 📄 Processing P28.ekg
# ✅ ECG Signal Processed! Length: 1089884 samples
# 📄 Processing P29.ekg
# ✅ ECG Signal Processed! Length: 681964 samples
# 📄 Processing P3.ekg
# ✅ ECG Signal Processed! Length: 371564 samples
# 📄 Processing P30.ekg
# ✅ ECG Signal Processed! Length: 589544 samples
# 📄 Processing P31.ekg
# ✅ ECG Signal Processed! Length: 314004 samples
# 📄 Processing P32.ekg
# ✅ ECG Signal Processed! Length: 371464 samples
# 📄 Processing P33.ekg
# ✅ ECG Signal Processed! Length: 364504 samples
# 📄 Processing P34.ekg
# ✅ ECG Signal Processed! Length: 437564 samples
# 📄 Processing P35.ekg
# ✅ ECG Signal Processed! Length: 313724 samples
# 📄 Processing P36.ekg
# ✅ ECG Signal Processed! Length: 663924 samples
# 📄 Processing P37.ekg
# ✅ ECG Signal Processed! Length: 560304 samples
# 📄 Processing P38.ekg
# ✅ ECG Signal Processed! Length: 308184 samples
# 📄 Processing P39.ekg
# ✅ ECG Signal Processed! Length: 288504 samples
# 📄 Processing P4.ekg
# ✅ ECG Signal Processed! Length: 241584 samples
# 📄 Processing P40.ekg
# ✅ ECG Signal Processed! Length: 336244 samples
# 📄 Processing P41.ekg
# ✅ ECG Signal Processed! Length: 266544 samples
# 📄 Processing P42.ekg
# ✅ ECG Signal Processed! Length: 373864 samples
# 📄 Processing P43.ekg
# ✅ ECG Signal Processed! Length: 264004 samples
# 📄 Processing P44.ekg
# ✅ ECG Signal Processed! Length: 218864 samples
# 📄 Processing P45.ekg
# ✅ ECG Signal Processed! Length: 479944 samples
# 📄 Processing P46.ekg
# ✅ ECG Signal Processed! Length: 261304 samples
# 📄 Processing P47.ekg
# ✅ ECG Signal Processed! Length: 245764 samples
# 📄 Processing P48.ekg
# ✅ ECG Signal Processed! Length: 371204 samples
# 📄 Processing P49.ekg
# ✅ ECG Signal Processed! Length: 498184 samples
# 📄 Processing P5.ekg
# ✅ ECG Signal Processed! Length: 487464 samples
# 📄 Processing P50.ekg
# ✅ ECG Signal Processed! Length: 623764 samples
# 📄 Processing P51.ekg
# ✅ ECG Signal Processed! Length: 248744 samples
# 📄 Processing P52.ekg
# ✅ ECG Signal Processed! Length: 409944 samples
# 📄 Processing P53.ekg
# ✅ ECG Signal Processed! Length: 1519564 samples
# 📄 Processing P54.ekg
# ✅ ECG Signal Processed! Length: 376824 samples
# 📄 Processing P55.ekg
# ✅ ECG Signal Processed! Length: 581564 samples
# 📄 Processing P56.ekg
# ✅ ECG Signal Processed! Length: 275744 samples
# 📄 Processing P57.ekg
# ✅ ECG Signal Processed! Length: 248424 samples
# 📄 Processing P58.ekg
# ✅ ECG Signal Processed! Length: 336384 samples
# 📄 Processing P59.ekg
# ✅ ECG Signal Processed! Length: 439064 samples
# 📄 Processing P6.ekg
# ✅ ECG Signal Processed! Length: 610424 samples
# 📄 Processing P60.ekg
# ✅ ECG Signal Processed! Length: 419524 samples
# 📄 Processing P61.ekg
# ✅ ECG Signal Processed! Length: 816104 samples
# 📄 Processing P62.ekg
# ✅ ECG Signal Processed! Length: 242024 samples
# 📄 Processing P63.ekg
# ✅ ECG Signal Processed! Length: 635164 samples
# 📄 Processing P64.ekg
# ✅ ECG Signal Processed! Length: 235344 samples
# 📄 Processing P65.ekg
# ✅ ECG Signal Processed! Length: 264044 samples
# 📄 Processing P66.ekg
# ✅ ECG Signal Processed! Length: 287964 samples
# 📄 Processing P67.ekg
# ✅ ECG Signal Processed! Length: 304484 samples
# 📄 Processing P68.ekg
# ✅ ECG Signal Processed! Length: 346084 samples
# 📄 Processing P69.ekg
# ✅ ECG Signal Processed! Length: 471224 samples
# 📄 Processing P7.ekg
# ✅ ECG Signal Processed! Length: 326344 samples
# 📄 Processing P70.ekg
# ✅ ECG Signal Processed! Length: 1360384 samples
# 📄 Processing P71.ekg
# ✅ ECG Signal Processed! Length: 2322004 samples
# 📄 Processing P72.ekg
# ✅ ECG Signal Processed! Length: 257644 samples
# 📄 Processing P73.ekg
# ✅ ECG Signal Processed! Length: 1040544 samples
# 📄 Processing P74.ekg
# ✅ ECG Signal Processed! Length: 438124 samples
# 📄 Processing P8.ekg
# ✅ ECG Signal Processed! Length: 800324 samples
# 📄 Processing P9.ekg
# ✅ ECG Signal Processed! Length: 472444 samples
