# %%
import numpy as np
import os

# 📌 Step 2: Load and Label ECG Data from Folders
def load_and_label_data(base_path):
    X = []
    y = []
    label_map = {'pre-inflation': 0, 'inflation': 1, 'post-inflation': 2}

    for folder_name, label in label_map.items():
        folder_path = os.path.join(base_path, folder_name)
        if not os.path.exists(folder_path):
            print(f"⚠️ Folder not found: {folder_path}")
            continue

        file_names = [f for f in os.listdir(folder_path) if f.endswith('.ekg')]
        print(f"📂 Reading {len(file_names)} files from {folder_name}")

        for file in file_names:
            file_path = os.path.join(folder_path, file)
            try:
                signal = np.fromfile(file_path, dtype=np.int16)
                if signal.size > 0:
                    signal = signal / np.max(np.abs(signal))  # normalize
                    X.append(signal[:5000])  # cut/pad to fixed length
                    y.append(label)
            except Exception as e:
                print(f"❌ Error reading {file}: {e}")

    return np.array(X), np.array(y)

# 🔹 Path jahan 3 folders hain
base_path = r"C:\Users\faizan\ECG_detection"  # <-- ✅ Update this to your path
X, y = load_and_label_data(base_path)

print(f"\n✅ Loaded {len(X)} ECG signals with shape {X.shape}")

# 📌 Step 3: Save All Cleaned Signals to Disk
output_folder = r"C:\Users\faizan\ECG_detection\cleaned_signals"  # <-- Full path to save
os.makedirs(output_folder, exist_ok=True)

for i, signal in enumerate(X):
    np.save(os.path.join(output_folder, f"signal_{i}.npy"), signal)
    print(f"✅ Saved: signal_{i}.npy")

# Save labels
np.save(os.path.join(output_folder, "labels.npy"), y)
print("✅ Labels saved as labels.npy")
# Out:
# 📂 Reading 74 files from pre-inflation
# 📂 Reading 74 files from inflation
# 📂 Reading 74 files from post-inflation
#
# ✅ Loaded 222 ECG signals with shape (222, 5000)
# ✅ Saved: signal_0.npy
# ✅ Saved: signal_1.npy
# ✅ Saved: signal_2.npy
# ✅ Saved: signal_3.npy
# ✅ Saved: signal_4.npy
# ✅ Saved: signal_5.npy
# ✅ Saved: signal_6.npy
# ✅ Saved: signal_7.npy
# ✅ Saved: signal_8.npy
# ✅ Saved: signal_9.npy
# ✅ Saved: signal_10.npy
# ✅ Saved: signal_11.npy
# ✅ Saved: signal_12.npy
# ✅ Saved: signal_13.npy
# ✅ Saved: signal_14.npy
# ✅ Saved: signal_15.npy
# ✅ Saved: signal_16.npy
# ✅ Saved: signal_17.npy
# ✅ Saved: signal_18.npy
# ✅ Saved: signal_19.npy
# ✅ Saved: signal_20.npy
# ✅ Saved: signal_21.npy
# ✅ Saved: signal_22.npy
# ✅ Saved: signal_23.npy
# ✅ Saved: signal_24.npy
# ✅ Saved: signal_25.npy
# ✅ Saved: signal_26.npy
# ✅ Saved: signal_27.npy
# ✅ Saved: signal_28.npy
# ✅ Saved: signal_29.npy
# ✅ Saved: signal_30.npy
# ✅ Saved: signal_31.npy
# ✅ Saved: signal_32.npy
# ✅ Saved: signal_33.npy
# ✅ Saved: signal_34.npy
# ✅ Saved: signal_35.npy
# ✅ Saved: signal_36.npy
# ✅ Saved: signal_37.npy
# ✅ Saved: signal_38.npy
# ✅ Saved: signal_39.npy
# ✅ Saved: signal_40.npy
# ✅ Saved: signal_41.npy
# ✅ Saved: signal_42.npy
# ✅ Saved: signal_43.npy
# ✅ Saved: signal_44.npy
# ✅ Saved: signal_45.npy
# ✅ Saved: signal_46.npy
# ✅ Saved: signal_47.npy
# ✅ Saved: signal_48.npy
# ✅ Saved: signal_49.npy
# ✅ Saved: signal_50.npy
# ✅ Saved: signal_51.npy
# ✅ Saved: signal_52.npy
# ✅ Saved: signal_53.npy
# ✅ Saved: signal_54.npy
# ✅ Saved: signal_55.npy
# ✅ Saved: signal_56.npy
# ✅ Saved: signal_57.npy
# ✅ Saved: signal_58.npy
# ✅ Saved: signal_59.npy
# ✅ Saved: signal_60.npy
# ✅ Saved: signal_61.npy
# ✅ Saved: signal_62.npy
# ✅ Saved: signal_63.npy
# ✅ Saved: signal_64.npy
# ✅ Saved: signal_65.npy
# ✅ Saved: signal_66.npy
# ✅ Saved: signal_67.npy
# ✅ Saved: signal_68.npy
# ✅ Saved: signal_69.npy
# ✅ Saved: signal_70.npy
# ✅ Saved: signal_71.npy
# ✅ Saved: signal_72.npy
# ✅ Saved: signal_73.npy
# ✅ Saved: signal_74.npy
# ✅ Saved: signal_75.npy
# ✅ Saved: signal_76.npy
# ✅ Saved: signal_77.npy
# ✅ Saved: signal_78.npy
# ✅ Saved: signal_79.npy
# ✅ Saved: signal_80.npy
# ✅ Saved: signal_81.npy
# ✅ Saved: signal_82.npy
# ✅ Saved: signal_83.npy
# ✅ Saved: signal_84.npy
# ✅ Saved: signal_85.npy
# ✅ Saved: signal_86.npy
# ✅ Saved: signal_87.npy
# ✅ Saved: signal_88.npy
# ✅ Saved: signal_89.npy
# ✅ Saved: signal_90.npy
# ✅ Saved: signal_91.npy
# ✅ Saved: signal_92.npy
# ✅ Saved: signal_93.npy
# ✅ Saved: signal_94.npy
# ✅ Saved: signal_95.npy
# ✅ Saved: signal_96.npy
# ✅ Saved: signal_97.npy
# ✅ Saved: signal_98.npy
# ✅ Saved: signal_99.npy
# ✅ Saved: signal_100.npy
# ✅ Saved: signal_101.npy
# ✅ Saved: signal_102.npy
# ✅ Saved: signal_103.npy
# ✅ Saved: signal_104.npy
# ✅ Saved: signal_105.npy
# ✅ Saved: signal_106.npy
# ✅ Saved: signal_107.npy
# ✅ Saved: signal_108.npy
# ✅ Saved: signal_109.npy
# ✅ Saved: signal_110.npy
# ✅ Saved: signal_111.npy
# ✅ Saved: signal_112.npy
# ✅ Saved: signal_113.npy
# ✅ Saved: signal_114.npy
# ✅ Saved: signal_115.npy
# ✅ Saved: signal_116.npy
# ✅ Saved: signal_117.npy
# ✅ Saved: signal_118.npy
# ✅ Saved: signal_119.npy
# ✅ Saved: signal_120.npy
# ✅ Saved: signal_121.npy
# ✅ Saved: signal_122.npy
# ✅ Saved: signal_123.npy
# ✅ Saved: signal_124.npy
# ✅ Saved: signal_125.npy
# ✅ Saved: signal_126.npy
# ✅ Saved: signal_127.npy
# ✅ Saved: signal_128.npy
# ✅ Saved: signal_129.npy
# ✅ Saved: signal_130.npy
# ✅ Saved: signal_131.npy
# ✅ Saved: signal_132.npy
# ✅ Saved: signal_133.npy
# ✅ Saved: signal_134.npy
# ✅ Saved: signal_135.npy
# ✅ Saved: signal_136.npy
# ✅ Saved: signal_137.npy
# ✅ Saved: signal_138.npy
# ✅ Saved: signal_139.npy
# ✅ Saved: signal_140.npy
# ✅ Saved: signal_141.npy
# ✅ Saved: signal_142.npy
# ✅ Saved: signal_143.npy
# ✅ Saved: signal_144.npy
# ✅ Saved: signal_145.npy
# ✅ Saved: signal_146.npy
# ✅ Saved: signal_147.npy
# ✅ Saved: signal_148.npy
# ✅ Saved: signal_149.npy
# ✅ Saved: signal_150.npy
# ✅ Saved: signal_151.npy
# ✅ Saved: signal_152.npy
# ✅ Saved: signal_153.npy
# ✅ Saved: signal_154.npy
# ✅ Saved: signal_155.npy
# ✅ Saved: signal_156.npy
# ✅ Saved: signal_157.npy
# ✅ Saved: signal_158.npy
# ✅ Saved: signal_159.npy
# ✅ Saved: signal_160.npy
# ✅ Saved: signal_161.npy
# ✅ Saved: signal_162.npy
# ✅ Saved: signal_163.npy
# ✅ Saved: signal_164.npy
# ✅ Saved: signal_165.npy
# ✅ Saved: signal_166.npy
# ✅ Saved: signal_167.npy
# ✅ Saved: signal_168.npy
# ✅ Saved: signal_169.npy
# ✅ Saved: signal_170.npy
# ✅ Saved: signal_171.npy
# ✅ Saved: signal_172.npy
# ✅ Saved: signal_173.npy
# ✅ Saved: signal_174.npy
# ✅ Saved: signal_175.npy
# ✅ Saved: signal_176.npy
# ✅ Saved: signal_177.npy
# ✅ Saved: signal_178.npy
# ✅ Saved: signal_179.npy
# ✅ Saved: signal_180.npy
# ✅ Saved: signal_181.npy
# ✅ Saved: signal_182.npy
# ✅ Saved: signal_183.npy
# ✅ Saved: signal_184.npy
# ✅ Saved: signal_185.npy
# ✅ Saved: signal_186.npy
# ✅ Saved: signal_187.npy
# ✅ Saved: signal_188.npy
# ✅ Saved: signal_189.npy
# ✅ Saved: signal_190.npy
# ✅ Saved: signal_191.npy
# ✅ Saved: signal_192.npy
# ✅ Saved: signal_193.npy
# ✅ Saved: signal_194.npy
# ✅ Saved: signal_195.npy
# ✅ Saved: signal_196.npy
# ✅ Saved: signal_197.npy
# ✅ Saved: signal_198.npy
# ✅ Saved: signal_199.npy
# ✅ Saved: signal_200.npy
# ✅ Saved: signal_201.npy
# ✅ Saved: signal_202.npy
# ✅ Saved: signal_203.npy
# ✅ Saved: signal_204.npy
# ✅ Saved: signal_205.npy
# ✅ Saved: signal_206.npy
# ✅ Saved: signal_207.npy
# ✅ Saved: signal_208.npy
# ✅ Saved: signal_209.npy
# ✅ Saved: signal_210.npy
# ✅ Saved: signal_211.npy
# ✅ Saved: signal_212.npy
# ✅ Saved: signal_213.npy
# ✅ Saved: signal_214.npy
# ✅ Saved: signal_215.npy
# ✅ Saved: signal_216.npy
# ✅ Saved: signal_217.npy
# ✅ Saved: signal_218.npy
# ✅ Saved: signal_219.npy
# ✅ Saved: signal_220.npy
# ✅ Saved: signal_221.npy
# ✅ Labels saved as labels.npy
